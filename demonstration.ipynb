# %%
from importlib.resources import files

import files
from files import group_and_aggregate_data

# %% [markdown]
# <h3> demonstrate load_data function: </h3>
# <p>
# using the attached ecxel file we recieved for this exercise
# </p>

# %%
df = files.load_data("knesset_25.xlsx")
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               city_name  ballot_code  party_avoda  \
# 0       אבו גווייעד שבט          3.1            0
# 1       אבו גווייעד שבט          3.2            1
# 2       אבו גווייעד שבט          3.3            0
# 3       אבו גווייעד שבט          3.4            0
# 4               אבו גוש          1.1            1
# ...                 ...          ...          ...
# 12540              תקוע          3.0            4
# 12541              תקוע          4.0            6
# 12542  תראבין אצאנע שבט          1.0            0
# 12543  תראבין אצאנעישוב          1.0            1
# 12544              תרום          1.0            5
#
#        party_shahar_kalkali_hadash  party_bayit_yehudi  party_agudat_israel  \
# 0                                0                   0                    0
# 1                                0                   0                    0
# 2                                0                   0                    0
# ...

# %% [markdown]
# <h3> demonstrate group_and_aggregate_data functions: </h3>
# <ul>
# <li>Aggregating it by city name.</li>
# <li>Displaying the total number of votes each party received in each city.</li>
# </ul>
